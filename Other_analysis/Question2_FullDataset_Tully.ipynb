# %%
# Import statments and plot figures inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Read in the produce dataset
a = pd.read_csv('produce_dataset_segments.csv')
a.head()
# Out:
#    Unnamed: 0  user_id  order_number  order_id  order_dow  order_hour_of_day  \
# 0           0        1             2   2398795          3                  7
# 1           1        1             5    431534          4                 15
# 2           2        1             5    431534          4                 15
# 3           3        1             5    431534          4                 15
# 4           4        1             5    431534          4                 15
#
#    days_since_prior_order  product_id            product_name  \
# 0                    15.0       13176  Bag of Organic Bananas
# 1                    28.0       10326     Organic Fuji Apples
# 2                    28.0       17122       Honeycrisp Apples
# 3                    28.0       41787          Bartlett Pears
# 4                    28.0       13176  Bag of Organic Bananas
#
#    add_to_cart_order  reordered  aisle_id         aisle  produce_item_flag  \
# 0                  4          0        24  fresh fruits                  1
# 1                  5          0        24  fresh fruits                  1
# 2                  6          0        24  fresh fruits                  1
# 3                  7          0        24  fresh fruits                  1
# 4                  8          1        24  fresh fruits                  1
#
#    organic_item_flag  cust_total_produce_purchased  \
# 0                  1                             5
# 1                  1                             5
# 2                  0                             5
# 3                  0                             5
# 4                  1                             5
#
#    cust_organic_produce_purchased  organic_%           segment
# 0                               3        0.6  Moderate Organic
# 1                               3        0.6  Moderate Organic
# 2                               3        0.6  Moderate Organic
# 3                               3        0.6  Moderate Organic
# 4                               3        0.6  Moderate Organic

# %%
# This returns a df with user_id, segment
by_user_id = a.groupby('user_id')[['segment']].first().reset_index()
by_user_id
# Out:
#         user_id           segment
# 0             1  Moderate Organic
# 1             2    Organic Taster
# 2             3  Moderate Organic
# 3             4     Super Organic
# 4             5  Moderate Organic
# ...         ...               ...
# 194326   206205  Moderate Organic
# 194327   206206  Moderate Organic
# 194328   206207     Super Organic
# 194329   206208  Moderate Organic
# 194330   206209    Organic Taster
#
# [194331 rows x 2 columns]

# %%
# Read in the complete dataset
b = pd.read_csv('complete_dataset.csv')
b.head()
# Out:
#    Unnamed: 0  user_id  order_number  order_id  order_dow  order_hour_of_day  \
# 0    24076664        1             1   2539329          2                  8
# 1    24076665        1             1   2539329          2                  8
# 2    24076666        1             1   2539329          2                  8
# 3    24076667        1             1   2539329          2                  8
# 4    24076668        1             1   2539329          2                  8
#
#    days_since_prior_order  product_id  \
# 0                     NaN         196
# 1                     NaN       14084
# 2                     NaN       12427
# 3                     NaN       26088
# 4                     NaN       26405
#
#                               product_name  add_to_cart_order  reordered  \
# 0                                     Soda                  1          0
# 1  Organic Unsweetened Vanilla Almond Milk                  2          0
# 2                      Original Beef Jerky                  3          0
# 3               Aged White Cheddar Popcorn                  4          0
# 4         XL Pick-A-Size Paper Towel Rolls                  5          0
#
#    aisle_id            aisle  department_id  department
# 0        77      soft drinks              7   beverages
# 1        91  soy lactosefree             16  dairy eggs
# 2        23    popcorn jerky             19      snacks
# 3        23    popcorn jerky             19      snacks
# 4        54      paper goods             17   household

# %%
# Initialize a item purchased flag column with all 1's, will use this to sum the total items purchased by segment
b['item_purchased_flag'] = 1
b.head()
# Out:
#    Unnamed: 0  user_id  order_number  order_id  order_dow  order_hour_of_day  \
# 0    24076664        1             1   2539329          2                  8
# 1    24076665        1             1   2539329          2                  8
# 2    24076666        1             1   2539329          2                  8
# 3    24076667        1             1   2539329          2                  8
# 4    24076668        1             1   2539329          2                  8
#
#    days_since_prior_order  product_id  \
# 0                     NaN         196
# 1                     NaN       14084
# 2                     NaN       12427
# 3                     NaN       26088
# 4                     NaN       26405
#
#                               product_name  add_to_cart_order  reordered  \
# 0                                     Soda                  1          0
# 1  Organic Unsweetened Vanilla Almond Milk                  2          0
# 2                      Original Beef Jerky                  3          0
# 3               Aged White Cheddar Popcorn                  4          0
# 4         XL Pick-A-Size Paper Towel Rolls                  5          0
#
#    aisle_id            aisle  department_id  department  item_purchased_flag
# 0        77      soft drinks              7   beverages                    1
# 1        91  soy lactosefree             16  dairy eggs                    1
# 2        23    popcorn jerky             19      snacks                    1
# 3        23    popcorn jerky             19      snacks                    1
# 4        54      paper goods             17   household                    1

# %%
# merge complete dataset called b (that has all purchases) with by_user_id that has user defined segment for each user_id
c = pd.merge(b, by_user_id, how='left', left_on = 'user_id', right_on = 'user_id')
c
# Out:
#           Unnamed: 0  user_id  order_number  order_id  order_dow  \
# 0           24076664        1             1   2539329          2
# 1           24076665        1             1   2539329          2
# 2           24076666        1             1   2539329          2
# 3           24076667        1             1   2539329          2
# 4           24076668        1             1   2539329          2
# ...              ...      ...           ...       ...        ...
# 33819101    32545756   206209            14    272231          6
# 33819102    32545757   206209            14    272231          6
# 33819103    32545758   206209            14    272231          6
# 33819104    32545759   206209            14    272231          6
# 33819105    32545760   206209            14    272231          6
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# 2                         8                     NaN       12427
# 3                         8                     NaN       26088
# 4                         8                     NaN       26405
# ...                     ...                     ...         ...
# 33819101                 14                    30.0       40603
# 33819102                 14                    30.0       15655
# 33819103                 14                    30.0       42606
# 33819104                 14                    30.0       37966
# 33819105                 14                    30.0       39216
#
#                                      product_name  add_to_cart_order  \
# 0                                            Soda                  1
# 1         Organic Unsweetened Vanilla Almond Milk                  2
# 2                             Original Beef Jerky                  3
# 3                      Aged White Cheddar Popcorn                  4
# 4                XL Pick-A-Size Paper Towel Rolls                  5
# ...                                           ...                ...
# 33819101                   Fabric Softener Sheets                  4
# 33819102   Dark Chocolate Mint Snacking Chocolate                  5
# 33819103                 Phish Food Frozen Yogurt                  6
# 33819104                    French Baguette Bread                  7
# 33819105     Original Multigrain Spoonfuls Cereal                  8
#
#           reordered  aisle_id            aisle  department_id  department  \
# 0                 0        77      soft drinks              7   beverages
# 1                 0        91  soy lactosefree             16  dairy eggs
# 2                 0        23    popcorn jerky             19      snacks
# 3                 0        23    popcorn jerky             19      snacks
# 4                 0        54      paper goods             17   household
# ...             ...       ...              ...            ...         ...
# 33819101          0        75          laundry             17   household
# 33819102          0        45  candy chocolate             19      snacks
# 33819103          0        37    ice cream ice              1      frozen
# 33819104          0       112            bread              3      bakery
# 33819105          1       121           cereal             14   breakfast
#
#           item_purchased_flag           segment
# 0                           1  Moderate Organic
# 1                           1  Moderate Organic
# 2                           1  Moderate Organic
# 3                           1  Moderate Organic
# 4                           1  Moderate Organic
# ...                       ...               ...
# 33819101                    1    Organic Taster
# 33819102                    1    Organic Taster
# 33819103                    1    Organic Taster
# 33819104                    1    Organic Taster
# 33819105                    1    Organic Taster
#
# [33819106 rows x 17 columns]

# %%
c = c.drop(['department_id', 'aisle_id', 'reordered'], axis=1)
c
# Out:
#           Unnamed: 0  user_id  order_number  order_id  order_dow  \
# 0           24076664        1             1   2539329          2
# 1           24076665        1             1   2539329          2
# 2           24076666        1             1   2539329          2
# 3           24076667        1             1   2539329          2
# 4           24076668        1             1   2539329          2
# ...              ...      ...           ...       ...        ...
# 33819101    32545756   206209            14    272231          6
# 33819102    32545757   206209            14    272231          6
# 33819103    32545758   206209            14    272231          6
# 33819104    32545759   206209            14    272231          6
# 33819105    32545760   206209            14    272231          6
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# 2                         8                     NaN       12427
# 3                         8                     NaN       26088
# 4                         8                     NaN       26405
# ...                     ...                     ...         ...
# 33819101                 14                    30.0       40603
# 33819102                 14                    30.0       15655
# 33819103                 14                    30.0       42606
# 33819104                 14                    30.0       37966
# 33819105                 14                    30.0       39216
#
#                                      product_name  add_to_cart_order  \
# 0                                            Soda                  1
# 1         Organic Unsweetened Vanilla Almond Milk                  2
# 2                             Original Beef Jerky                  3
# 3                      Aged White Cheddar Popcorn                  4
# 4                XL Pick-A-Size Paper Towel Rolls                  5
# ...                                           ...                ...
# 33819101                   Fabric Softener Sheets                  4
# 33819102   Dark Chocolate Mint Snacking Chocolate                  5
# 33819103                 Phish Food Frozen Yogurt                  6
# 33819104                    French Baguette Bread                  7
# 33819105     Original Multigrain Spoonfuls Cereal                  8
#
#                     aisle  department  item_purchased_flag           segment
# 0             soft drinks   beverages                    1  Moderate Organic
# 1         soy lactosefree  dairy eggs                    1  Moderate Organic
# 2           popcorn jerky      snacks                    1  Moderate Organic
# 3           popcorn jerky      snacks                    1  Moderate Organic
# 4             paper goods   household                    1  Moderate Organic
# ...                   ...         ...                  ...               ...
# 33819101          laundry   household                    1    Organic Taster
# 33819102  candy chocolate      snacks                    1    Organic Taster
# 33819103    ice cream ice      frozen                    1    Organic Taster
# 33819104            bread      bakery                    1    Organic Taster
# 33819105           cereal   breakfast                    1    Organic Taster
#
# [33819106 rows x 14 columns]

# %%
# For one column using pandas: df['DataFrame Column'] = df['DataFrame Column'].fillna(0)
c['segment'] = c['segment'].fillna('No Produce')
c
# Out:
#           Unnamed: 0  user_id  order_number  order_id  order_dow  \
# 0           24076664        1             1   2539329          2
# 1           24076665        1             1   2539329          2
# 2           24076666        1             1   2539329          2
# 3           24076667        1             1   2539329          2
# 4           24076668        1             1   2539329          2
# ...              ...      ...           ...       ...        ...
# 33819101    32545756   206209            14    272231          6
# 33819102    32545757   206209            14    272231          6
# 33819103    32545758   206209            14    272231          6
# 33819104    32545759   206209            14    272231          6
# 33819105    32545760   206209            14    272231          6
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# 2                         8                     NaN       12427
# 3                         8                     NaN       26088
# 4                         8                     NaN       26405
# ...                     ...                     ...         ...
# 33819101                 14                    30.0       40603
# 33819102                 14                    30.0       15655
# 33819103                 14                    30.0       42606
# 33819104                 14                    30.0       37966
# 33819105                 14                    30.0       39216
#
#                                      product_name  add_to_cart_order  \
# 0                                            Soda                  1
# 1         Organic Unsweetened Vanilla Almond Milk                  2
# 2                             Original Beef Jerky                  3
# 3                      Aged White Cheddar Popcorn                  4
# 4                XL Pick-A-Size Paper Towel Rolls                  5
# ...                                           ...                ...
# 33819101                   Fabric Softener Sheets                  4
# 33819102   Dark Chocolate Mint Snacking Chocolate                  5
# 33819103                 Phish Food Frozen Yogurt                  6
# 33819104                    French Baguette Bread                  7
# 33819105     Original Multigrain Spoonfuls Cereal                  8
#
#                     aisle  department  item_purchased_flag           segment
# 0             soft drinks   beverages                    1  Moderate Organic
# 1         soy lactosefree  dairy eggs                    1  Moderate Organic
# 2           popcorn jerky      snacks                    1  Moderate Organic
# 3           popcorn jerky      snacks                    1  Moderate Organic
# 4             paper goods   household                    1  Moderate Organic
# ...                   ...         ...                  ...               ...
# 33819101          laundry   household                    1    Organic Taster
# 33819102  candy chocolate      snacks                    1    Organic Taster
# 33819103    ice cream ice      frozen                    1    Organic Taster
# 33819104            bread      bakery                    1    Organic Taster
# 33819105           cereal   breakfast                    1    Organic Taster
#
# [33819106 rows x 14 columns]

# %%
# create a df that is grouped by organic segment
by_segment_c = c.groupby('segment')
by_segment_c

# %%
by_segment_c.head()
# Out:
#       Unnamed: 0  user_id  order_number  order_id  order_dow  \
# 0       24076664        1             1   2539329          2
# 1       24076665        1             1   2539329          2
# 2       24076666        1             1   2539329          2
# 3       24076667        1             1   2539329          2
# 4       24076668        1             1   2539329          2
# 70      20554981        2             1   2168274          2
# 71      20554982        2             1   2168274          2
# 72      20554983        2             1   2168274          2
# 73      20554984        2             1   2168274          2
# 74      20554985        2             1   2168274          2
# 384     31695751        4             1   3343014          6
# 385     31695752        4             1   3343014          6
# 386     31695753        4             1   3343014          6
# 387     31695754        4             1   3343014          6
# 388     19249953        4             2   2030307          4
# 1464    23840337       15             1   2514324          5
# 1465    23840338       15             1   2514324          5
# 1466    23840339       15             1   2514324          5
# 1467    23840340       15             1   2514324          5
# 1468    29732460       15             2   3135826          6
# 1606    16472702       17             1   1737705          2
# 1607    16472703       17             1   1737705          2
# 1608    16472704       17             1   1737705          2
# 1609    15936386       17             2   1681401          5
# 1610    15936387       17             2   1681401          5
#
#       order_hour_of_day  days_since_prior_order  product_id  \
# 0                     8                     NaN         196
# 1                     8                     NaN       14084
# 2                     8                     NaN       12427
# 3                     8                     NaN       26088
# 4                     8                     NaN       26405
# 70                   11                     NaN       32792
# 71                   11                     NaN       47766
# 72                   11                     NaN       20574
# 73                   11                     NaN       12000
# 74                   11                     NaN       48110
# 384                  11                     NaN       36606
# 385                  11                     NaN        7350
# 386                  11                     NaN       35469
# 387                  11                     NaN        2707
# 388                  11                    19.0       42329
# 1464                 13                     NaN       11266
# 1465                 13                     NaN       12427
# 1466                 13                     NaN       10441
# 1467                 13                     NaN       14715
# 1468                 12                    15.0       37710
# 1606                 13                     NaN        7350
# 1607                 13                     NaN       47141
# 1608                 13                     NaN       17762
# 1609                 10                     3.0        7350
# 1610                 10                     3.0       18534
#
#                                            product_name  add_to_cart_order  \
# 0                                                  Soda                  1
# 1               Organic Unsweetened Vanilla Almond Milk                  2
# 2                                   Original Beef Jerky                  3
# 3                            Aged White Cheddar Popcorn                  4
# 4                      XL Pick-A-Size Paper Towel Rolls                  5
# 70                       Chipotle Beef & Pork Realstick                  1
# 71                                      Organic Avocado                  2
# 72                                       Roasted Turkey                  3
# 73             Baked Organic Sea Salt Crunchy Pea Snack                  4
# 74              Thin Stackers Brown Rice Lightly Salted                  5
# 384                          Sprouted Multi-Grain Bread                  1
# 385         Natural Lime Flavor Sparkling Mineral Water                  2
# 386                      Enchilada Black Bean Vegetable                  3
# 387   Complete™ ActionPacs™ Fresh Scent Dishwasher D...                  4
# 388                        Private Selection Pinot Noir                  1
# 1464                                       Dried Mangos                  1
# 1465                                Original Beef Jerky                  2
# 1466                                Dry Roasted Almonds                  3
# 1467                                      Coconut Water                  4
# 1468                                          Trail Mix                  1
# 1606        Natural Lime Flavor Sparkling Mineral Water                  1
# 1607                                               Cola                  2
# 1608                             Light Oaked Chardonnay                  3
# 1609        Natural Lime Flavor Sparkling Mineral Water                  1
# 1610                           Grade A Extra Large Eggs                  2
#
#                               aisle  department  item_purchased_flag  \
# 0                       soft drinks   beverages                    1
# 1                   soy lactosefree  dairy eggs                    1
# 2                     popcorn jerky      snacks                    1
# 3                     popcorn jerky      snacks                    1
# 4                       paper goods   household                    1
# 70                    popcorn jerky      snacks                    1
# 71                     fresh fruits     produce                    1
# 72                       lunch meat        deli                    1
# 73                       condiments      pantry                    1
# 74                         crackers      snacks                    1
# 384                           bread      bakery                    1
# 385   water seltzer sparkling water   beverages                    1
# 386                    frozen meals      frozen                    1
# 387                 dish detergents   household                    1
# 388                       red wines     alcohol                    1
# 1464         nuts seeds dried fruit      snacks                    1
# 1465                  popcorn jerky      snacks                    1
# 1466         nuts seeds dried fruit      snacks                    1
# 1467                  juice nectars   beverages                    1
# 1468            trail mix snack mix      snacks                    1
# 1606  water seltzer sparkling water   beverages                    1
# 1607                    soft drinks   beverages                    1
# 1608                    white wines     alcohol                    1
# 1609  water seltzer sparkling water   beverages                    1
# 1610                           eggs  dairy eggs                    1
#
#                segment
# 0     Moderate Organic
# 1     Moderate Organic
# 2     Moderate Organic
# 3     Moderate Organic
# 4     Moderate Organic
# 70      Organic Taster
# 71      Organic Taster
# 72      Organic Taster
# 73      Organic Taster
# 74      Organic Taster
# 384      Super Organic
# 385      Super Organic
# 386      Super Organic
# 387      Super Organic
# 388      Super Organic
# 1464        No Produce
# 1465        No Produce
# 1466        No Produce
# 1467        No Produce
# 1468        No Produce
# 1606     Never Organic
# 1607     Never Organic
# 1608     Never Organic
# 1609     Never Organic
# 1610     Never Organic

# %%
# build dictionary of functions to aggregate onto by_segment for analysis
func_dict = {'user_id':'nunique', 'order_id':'nunique', 'item_purchased_flag':'sum',
             'days_since_prior_order':'mean', 'order_dow':'mean', 'order_hour_of_day':'mean'}

# %%
# apply function dicitonary to by_segment
segment_behavior_df_c = by_segment_c.agg(func_dict)
segment_behavior_df_c
# Out:
#                   user_id  order_id  item_purchased_flag  \
# segment
# Moderate Organic    80773   1491633             16583189
# Never Organic       29939    391941              3389480
# No Produce          11878    107685               481760
# Organic Taster      70338   1160841             11650123
# Super Organic       13281    193983              1714554
#
#                   days_since_prior_order  order_dow  order_hour_of_day
# segment
# Moderate Organic               10.746269   2.700714          13.463552
# Never Organic                  12.728888   2.836592          13.388210
# No Produce                     14.977034   2.923987          13.130565
# Organic Taster                 11.788277   2.749822          13.394468
# Super Organic                  10.893216   2.757042          13.537843

# %%
# add two columns: (1) calculate the shopping cart size and (2) How % of produce items that are re-ordered
segment_behavior_df_c['avg_order_count'] = segment_behavior_df_c['order_id']/segment_behavior_df_c['user_id']
segment_behavior_df_c['avg_order_size'] = segment_behavior_df_c['item_purchased_flag']/segment_behavior_df_c['order_id']
segment_behavior_df_c
# Out:
#                   user_id  order_id  item_purchased_flag  \
# segment
# Moderate Organic    80773   1491633             16583189
# Never Organic       29939    391941              3389480
# No Produce          11878    107685               481760
# Organic Taster      70338   1160841             11650123
# Super Organic       13281    193983              1714554
#
#                   days_since_prior_order  order_dow  order_hour_of_day  \
# segment
# Moderate Organic               10.746269   2.700714          13.463552
# Never Organic                  12.728888   2.836592          13.388210
# No Produce                     14.977034   2.923987          13.130565
# Organic Taster                 11.788277   2.749822          13.394468
# Super Organic                  10.893216   2.757042          13.537843
#
#                   avg_order_count  avg_order_size
# segment
# Moderate Organic        18.466975       11.117473
# Never Organic           13.091319        8.647934
# No Produce               9.065920        4.473789
# Organic Taster          16.503753       10.035933
# Super Organic           14.606054        8.838682

# %%
# change index order to reflect segmentation scale: Never to Super
segment_behavior_df_c = segment_behavior_df_c.reindex(index = ['No Produce','Never Organic','Organic Taster', 
                                                                       'Moderate Organic', 'Super Organic'])
segment_behavior_df_c.round(2)
# Out:
#                   user_id  order_id  item_purchased_flag  \
# segment
# No Produce          11878    107685               481760
# Never Organic       29939    391941              3389480
# Organic Taster      70338   1160841             11650123
# Moderate Organic    80773   1491633             16583189
# Super Organic       13281    193983              1714554
#
#                   days_since_prior_order  order_dow  order_hour_of_day  \
# segment
# No Produce                         14.98       2.92              13.13
# Never Organic                      12.73       2.84              13.39
# Organic Taster                     11.79       2.75              13.39
# Moderate Organic                   10.75       2.70              13.46
# Super Organic                      10.89       2.76              13.54
#
#                   avg_order_count  avg_order_size
# segment
# No Produce                   9.07            4.47
# Never Organic               13.09            8.65
# Organic Taster              16.50           10.04
# Moderate Organic            18.47           11.12
# Super Organic               14.61            8.84

# %%
#clean up dataframe columns by dropping ones not needed for final chart
segment_behavior_df__full_final = segment_behavior_df_c.drop(['user_id','order_id', 'item_purchased_flag', 'order_dow', 'order_hour_of_day'], axis=1) 
segment_behavior_df__full_final.round(2)
# Out:
#                   days_since_prior_order  avg_order_count  avg_order_size
# segment
# No Produce                         14.98             9.07            4.47
# Never Organic                      12.73            13.09            8.65
# Organic Taster                     11.79            16.50           10.04
# Moderate Organic                   10.75            18.47           11.12
# Super Organic                      10.89            14.61            8.84

# %%
# Rename the columns to explain what they actually are
segment_behavior_df__full_final.rename(columns = {'days_since_prior_order': 'Average # of days since last order', 
                                            'avg_order_count': 'Average # of orders', 
                                            'avg_order_size': 'Average order size'}, inplace = True)

segment_behavior_df__full_final.round(2)
# Out:
#                   Average # of days since last order  Average # of orders  \
# segment
# No Produce                                     14.98                 9.07
# Never Organic                                  12.73                13.09
# Organic Taster                                 11.79                16.50
# Moderate Organic                               10.75                18.47
# Super Organic                                  10.89                14.61
#
#                   Average order size
# segment
# No Produce                      4.47
# Never Organic                   8.65
# Organic Taster                 10.04
# Moderate Organic               11.12
# Super Organic                   8.84

# %%
#frame = frame[['column I want first', 'column I want second'...etc.]]
segment_behavior_df__full_final = segment_behavior_df__full_final[['Average # of orders', 'Average # of days since last order', 'Average order size']]
segment_behavior_df__full_final.round(1)
# Out:
#                   Average # of orders  Average # of days since last order  \
# segment
# No Produce                        9.1                                15.0
# Never Organic                    13.1                                12.7
# Organic Taster                   16.5                                11.8
# Moderate Organic                 18.5                                10.7
# Super Organic                    14.6                                10.9
#
#                   Average order size
# segment
# No Produce                       4.5
# Never Organic                    8.6
# Organic Taster                  10.0
# Moderate Organic                11.1
# Super Organic                    8.8

# %% [markdown]
# # Plots

# %%
my_pal = {"Never Organic": "#1F77B4", "Organic Taster": "#2CA02C", "Moderate Organic":"#FF7F0E", "Super Organic":"#D62728", "No Produce":"#808080"}

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'segment', y = 'days_since_prior_order', data = c, 
            order=['No Produce', "Never Organic", "Organic Taster", "Moderate Organic", 'Super Organic'], palette=my_pal, showfliers = False)
plt.title("Distribution of average days since prior order by segment (full dataset)")
plt.ylabel('# of days since last order')
plt.xlabel('Segment')
pass

# %%
fig, ax = plt.subplots(figsize=(7, 4))
sns.set_style("whitegrid")
sns.boxplot(x = 'segment', y = 'days_since_prior_order', data = c, 
            order=['No Produce', "Never Organic", "Organic Taster", "Moderate Organic", 'Super Organic'], palette=my_pal, showfliers = False)
plt.title("Distribution of average days since prior order by segment (full dataset)")
plt.ylabel('# of days since last order')
plt.xlabel('Segment')
pass

# %% [markdown]
# # Build DF where each row is a user_id

# %%
# This returns a series with user_id, total items purchased
user_total_full = c.groupby('user_id')['item_purchased_flag'].sum()
user_total_full
# Out:
# user_id
# 1          70
# 2         226
# 3          88
# 4          18
# 5          46
#          ...
# 206205     51
# 206206    285
# 206207    223
# 206208    677
# 206209    137
# Name: item_purchased_flag, Length: 206209, dtype: int64

# %%
# This returns a series with user_id, total of orders per user
user_orders_full = c.groupby('user_id')['order_id'].nunique()
user_orders_full
# Out:
# user_id
# 1         11
# 2         15
# 3         12
# 4          5
# 5          5
#           ..
# 206205     4
# 206206    67
# 206207    16
# 206208    49
# 206209    14
# Name: order_id, Length: 206209, dtype: int64

# %%
# This returns a series with user_id, Segmentation name
user_segment_full = c.groupby('user_id')[['segment']].first()
user_segment_full
# Out:
#                   segment
# user_id
# 1        Moderate Organic
# 2          Organic Taster
# 3        Moderate Organic
# 4           Super Organic
# 5        Moderate Organic
# ...                   ...
# 206205   Moderate Organic
# 206206   Moderate Organic
# 206207      Super Organic
# 206208   Moderate Organic
# 206209     Organic Taster
#
# [206209 rows x 1 columns]

# %%
# Combine the total and organic series into one dataframe (user_id, total_orders, organic?)
user_df_full_1 = pd.concat([user_total_full, user_orders_full], axis=1).reset_index()
user_df_full_1
# Out:
#         user_id  item_purchased_flag  order_id
# 0             1                   70        11
# 1             2                  226        15
# 2             3                   88        12
# 3             4                   18         5
# 4             5                   46         5
# ...         ...                  ...       ...
# 206204   206205                   51         4
# 206205   206206                  285        67
# 206206   206207                  223        16
# 206207   206208                  677        49
# 206208   206209                  137        14
#
# [206209 rows x 3 columns]

# %%
# merge with customer segment df
user_df_full_2 = pd.merge(user_df_full_1, user_segment_full, how='left', left_on = 'user_id', right_on = 'user_id')
user_df_full_2
# Out:
#         user_id  item_purchased_flag  order_id           segment
# 0             1                   70        11  Moderate Organic
# 1             2                  226        15    Organic Taster
# 2             3                   88        12  Moderate Organic
# 3             4                   18         5     Super Organic
# 4             5                   46         5  Moderate Organic
# ...         ...                  ...       ...               ...
# 206204   206205                   51         4  Moderate Organic
# 206205   206206                  285        67  Moderate Organic
# 206206   206207                  223        16     Super Organic
# 206207   206208                  677        49  Moderate Organic
# 206208   206209                  137        14    Organic Taster
#
# [206209 rows x 4 columns]

# %%
# Rename the oder_id column to total_produce_orders' & reordered to produce_items_reordered
user_df_full_2.rename(columns = {'order_id':'total_orders', 'item_purchased_flag' : 'total_items_purchased'}, inplace = True) 
user_df_full_2
# Out:
#         user_id  total_items_purchased  total_orders           segment  \
# 0             1                     70            11  Moderate Organic
# 1             2                    226            15    Organic Taster
# 2             3                     88            12  Moderate Organic
# 3             4                     18             5     Super Organic
# 4             5                     46             5  Moderate Organic
# ...         ...                    ...           ...               ...
# 206204   206205                     51             4  Moderate Organic
# 206205   206206                    285            67  Moderate Organic
# 206206   206207                    223            16     Super Organic
# 206207   206208                    677            49  Moderate Organic
# 206208   206209                    137            14    Organic Taster
#
#         avg_order_size
# 0             6.363636
# 1            15.066667
# 2             7.333333
# 3             3.600000
# 4             9.200000
# ...                ...
# 206204       12.750000
# 206205        4.253731
# 206206       13.937500
# 206207       13.816327
# 206208        9.785714
#
# [206209 rows x 5 columns]

# %%
user_df_full_2['avg_order_size'] = user_df_full_2['total_items_purchased']/user_df_full_2['total_orders']
user_df_full_2.round(2)
# Out:
#         user_id  total_items_purchased  total_orders           segment  \
# 0             1                     70            11  Moderate Organic
# 1             2                    226            15    Organic Taster
# 2             3                     88            12  Moderate Organic
# 3             4                     18             5     Super Organic
# 4             5                     46             5  Moderate Organic
# ...         ...                    ...           ...               ...
# 206204   206205                     51             4  Moderate Organic
# 206205   206206                    285            67  Moderate Organic
# 206206   206207                    223            16     Super Organic
# 206207   206208                    677            49  Moderate Organic
# 206208   206209                    137            14    Organic Taster
#
#         avg_order_size
# 0                 6.36
# 1                15.07
# 2                 7.33
# 3                 3.60
# 4                 9.20
# ...                ...
# 206204           12.75
# 206205            4.25
# 206206           13.94
# 206207           13.82
# 206208            9.79
#
# [206209 rows x 5 columns]

# %%
df = user_df_full_2
df
# Out:
#         user_id  total_items_purchased  total_orders           segment  \
# 0             1                     70            11  Moderate Organic
# 1             2                    226            15    Organic Taster
# 2             3                     88            12  Moderate Organic
# 3             4                     18             5     Super Organic
# 4             5                     46             5  Moderate Organic
# ...         ...                    ...           ...               ...
# 206204   206205                     51             4  Moderate Organic
# 206205   206206                    285            67  Moderate Organic
# 206206   206207                    223            16     Super Organic
# 206207   206208                    677            49  Moderate Organic
# 206208   206209                    137            14    Organic Taster
#
#         avg_order_size
# 0             6.363636
# 1            15.066667
# 2             7.333333
# 3             3.600000
# 4             9.200000
# ...                ...
# 206204       12.750000
# 206205        4.253731
# 206206       13.937500
# 206207       13.816327
# 206208        9.785714
#
# [206209 rows x 5 columns]

# %%
# For one column using pandas: df['DataFrame Column'] = df['DataFrame Column'].fillna(0)
df['segment'] = df['segment'].fillna('No Produce')
df
# Out:
#         user_id  total_items_purchased  total_orders           segment  \
# 0             1                     70            11  Moderate Organic
# 1             2                    226            15    Organic Taster
# 2             3                     88            12  Moderate Organic
# 3             4                     18             5     Super Organic
# 4             5                     46             5  Moderate Organic
# ...         ...                    ...           ...               ...
# 206204   206205                     51             4  Moderate Organic
# 206205   206206                    285            67  Moderate Organic
# 206206   206207                    223            16     Super Organic
# 206207   206208                    677            49  Moderate Organic
# 206208   206209                    137            14    Organic Taster
#
#         avg_order_size
# 0             6.363636
# 1            15.066667
# 2             7.333333
# 3             3.600000
# 4             9.200000
# ...                ...
# 206204       12.750000
# 206205        4.253731
# 206206       13.937500
# 206207       13.816327
# 206208        9.785714
#
# [206209 rows x 5 columns]

# %% [markdown]
# # Plot other box plot for Order # and Avg Order size per customer

# %%
fig, ax = plt.subplots(figsize=(7, 4))
sns.set_style("whitegrid")
sns.boxplot(x = 'segment', y = 'total_orders', data = df, 
            order=["No Produce" , "Never Organic", "Organic Taster", "Moderate Organic", 'Super Organic'], palette=my_pal, showfliers = False)
plt.title("Distribution of orders per customer by segment (full dataset)")
plt.ylabel('Total Orders per customer')
plt.xlabel('Segment')
# Out:
# Text(0.5, 0, 'Segment')

# %%
fig, ax = plt.subplots(figsize=(7, 4))
sns.set_style("whitegrid")
sns.boxplot(x = 'segment', y = 'avg_order_size', data = df, 
            order=["No Produce" , "Never Organic", "Organic Taster", "Moderate Organic", 'Super Organic'], palette=my_pal, showfliers = False)
plt.title("Distribution of order size per customer by segment (full dataset)")
plt.ylabel('Average order size per customer')
plt.xlabel('Segment')
# Out:
# Text(0.5, 0, 'Segment')
