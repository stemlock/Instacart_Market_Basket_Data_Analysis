# %%
# Import statments and plot figures inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn as sns

# %matplotlib inline

# %%
# Global variables to define ranges between segments

NEVER_ORGANIC_MAX = 0.1
MID = 0.5
SUPER_ORGANIC_MIN = 0.9

# %%
# Read in the produce dataset
organic = pd.read_csv('produce_dataset.csv')

# %%
# Drop the column of index from the previous table (no longer valid indices)
organic.drop('Unnamed: 0', axis =1, inplace=True)

# %%
# Dataset is ordered by user_id
organic.head(30)
# Out:
#     user_id  order_number  order_id  order_dow  order_hour_of_day  \
# 0         1             2   2398795          3                  7
# 1         1             5    431534          4                 15
# 2         1             5    431534          4                 15
# 3         1             5    431534          4                 15
# 4         1             5    431534          4                 15
# 5         2             1   2168274          2                 11
# 6         2             1   2168274          2                 11
# 7         2             1   2168274          2                 11
# 8         2             1   2168274          2                 11
# 9         2             2   1501582          5                 10
# 10        2             2   1501582          5                 10
# 11        2             3   1901567          1                 10
# 12        2             4    738281          2                 10
# 13        2             4    738281          2                 10
# 14        2             4    738281          2                 10
# 15        2             5   1673511          3                 11
# 16        2             6   1199898          2                  9
# 17        2             6   1199898          2                  9
# 18        2             6   1199898          2                  9
# 19        2             6   1199898          2                  9
# 20        2             6   1199898          2                  9
# 21        2             7   3194192          2                 12
# 22        2             7   3194192          2                 12
# 23        2             7   3194192          2                 12
# 24        2             7   3194192          2                 12
# 25        2             8    788338          1                 15
# 26        2             8    788338          1                 15
# 27        2             8    788338          1                 15
# 28        2             9   1718559          2                  9
# 29        2             9   1718559          2                  9
#
#     days_since_prior_order  product_id            product_name  \
# 0                     15.0       13176  Bag of Organic Bananas
# 1                     28.0       10326     Organic Fuji Apples
# 2                     28.0       17122       Honeycrisp Apples
# 3                     28.0       41787          Bartlett Pears
# 4                     28.0       13176  Bag of Organic Bananas
# 5                      NaN       47766         Organic Avocado
# 6                      NaN       27966     Organic Raspberries
# 7                      NaN       13176  Bag of Organic Bananas
# 8                      NaN       45066        Honeycrisp Apple
# 9                     10.0       16797            Strawberries
# 10                    10.0       47766         Organic Avocado
# 11                     3.0       47766         Organic Avocado
# 12                     8.0       37646     Organic Gala Apples
# 13                     8.0       24852                  Banana
# 14                     8.0       47209    Organic Hass Avocado
# 15                     8.0       47766         Organic Avocado
# 16                    13.0       24852                  Banana
# 17                    13.0       45066        Honeycrisp Apple
# 18                    13.0       27966     Organic Raspberries
# 19                    13.0       47209    Organic Hass Avocado
# 20                    13.0       41787          Bartlett Pears
# 21                    14.0       47209    Organic Hass Avocado
# 22                    14.0       24852                  Banana
# 23                    14.0       45066        Honeycrisp Apple
# 24                    14.0       41787          Bartlett Pears
# 25                    27.0       24852                  Banana
# 26                    27.0       47209    Organic Hass Avocado
# 27                    27.0        5212       Watermelon Chunks
# 28                     8.0       24852                  Banana
# 29                     8.0        5450      Small Hass Avocado
#
#     add_to_cart_order  reordered  aisle_id                       aisle
# 0                   4          0        24                fresh fruits
# 1                   5          0        24                fresh fruits
# 2                   6          0        24                fresh fruits
# 3                   7          0        24                fresh fruits
# 4                   8          1        24                fresh fruits
# 5                   2          0        24                fresh fruits
# 6                  11          0       123  packaged vegetables fruits
# 7                  12          0        24                fresh fruits
# 8                  13          0        24                fresh fruits
# 9                   1          0        24                fresh fruits
# 10                  4          1        24                fresh fruits
# 11                  1          1        24                fresh fruits
# 12                  6          0        24                fresh fruits
# 13                  8          0        24                fresh fruits
# 14                  9          0        24                fresh fruits
# 15                 13          1        24                fresh fruits
# 16                  7          1        24                fresh fruits
# 17                  8          1        24                fresh fruits
# 18                  9          1       123  packaged vegetables fruits
# 19                 10          1        24                fresh fruits
# 20                 19          0        24                fresh fruits
# 21                  7          1        24                fresh fruits
# 22                  8          1        24                fresh fruits
# 23                 12          1        24                fresh fruits
# 24                 13          1        24                fresh fruits
# 25                  3          1        24                fresh fruits
# 26                  6          1        24                fresh fruits
# 27                 15          0       123  packaged vegetables fruits
# 28                  2          1        24                fresh fruits
# 29                 17          0        24                fresh fruits

# %%
# Initialize a total_produce_purchased column with all 1's 
organic['total_produce_purchased'] = 1
organic
# Out:
#          user_id  order_number  order_id  order_dow  order_hour_of_day  \
# 0              1             2   2398795          3                  7
# 1              1             5    431534          4                 15
# 2              1             5    431534          4                 15
# 3              1             5    431534          4                 15
# 4              1             5    431534          4                 15
# ...          ...           ...       ...        ...                ...
# 9888373   206209            12    626363          1                 12
# 9888374   206209            12    626363          1                 12
# 9888375   206209            12    626363          1                 12
# 9888376   206209            13   2977660          1                 12
# 9888377   206209            14    272231          6                 14
#
#          days_since_prior_order  product_id  \
# 0                          15.0       13176
# 1                          28.0       10326
# 2                          28.0       17122
# 3                          28.0       41787
# 4                          28.0       13176
# ...                         ...         ...
# 9888373                    18.0       43961
# 9888374                    18.0        5622
# 9888375                    18.0       14727
# 9888376                     7.0       24852
# 9888377                    30.0       24852
#
#                               product_name  add_to_cart_order  reordered  \
# 0                   Bag of Organic Bananas                  4          0
# 1                      Organic Fuji Apples                  5          0
# 2                        Honeycrisp Apples                  6          0
# 3                           Bartlett Pears                  7          0
# 4                   Bag of Organic Bananas                  8          1
# ...                                    ...                ...        ...
# 9888373  Organic Peeled Whole Baby Carrots                 10          1
# 9888374      Cocktail Tomatoes on the Vine                 18          0
# 9888375                       Yellow Onion                 20          0
# 9888376                             Banana                  1          1
# 9888377                             Banana                  3          1
#
#          aisle_id                       aisle  total_produce_purchased
# 0              24                fresh fruits                        1
# 1              24                fresh fruits                        1
# 2              24                fresh fruits                        1
# 3              24                fresh fruits                        1
# 4              24                fresh fruits                        1
# ...           ...                         ...                      ...
# 9888373       123  packaged vegetables fruits                        1
# 9888374       123  packaged vegetables fruits                        1
# 9888375       123  packaged vegetables fruits                        1
# 9888376        24                fresh fruits                        1
# 9888377        24                fresh fruits                        1
#
# [9888378 rows x 13 columns]

# %%
unumord = organic.groupby('user_id')['order_number'].nunique()
unumord
# Out:
# user_id
# 1          2
# 2         15
# 3         12
# 4          1
# 5          5
#           ..
# 206205     3
# 206206    11
# 206207    16
# 206208    45
# 206209    11
# Name: order_number, Length: 194331, dtype: int64

# %%
# Group the rows by user_id and add the previously initialized total_produce_purchased column (each row is 1)
# This returns a series with user_id, total_produce_purchased
user_total = organic.groupby('user_id')['total_produce_purchased'].sum()
user_total
# Out:
# user_id
# 1           5
# 2          43
# 3          38
# 4           2
# 5          23
#          ...
# 206205     14
# 206206     34
# 206207     50
# 206208    197
# 206209     20
# Name: total_produce_purchased, Length: 194331, dtype: int64

# %%
# Create a organic? column containing 1 for an organic produce, 0 for a non-organic produce
organic['organic?'] = organic['product_name'].str.contains('Organic').astype(int)
organic
# Out:
#          user_id  order_number  order_id  order_dow  order_hour_of_day  \
# 0              1             2   2398795          3                  7
# 1              1             5    431534          4                 15
# 2              1             5    431534          4                 15
# 3              1             5    431534          4                 15
# 4              1             5    431534          4                 15
# ...          ...           ...       ...        ...                ...
# 9888373   206209            12    626363          1                 12
# 9888374   206209            12    626363          1                 12
# 9888375   206209            12    626363          1                 12
# 9888376   206209            13   2977660          1                 12
# 9888377   206209            14    272231          6                 14
#
#          days_since_prior_order  product_id  \
# 0                          15.0       13176
# 1                          28.0       10326
# 2                          28.0       17122
# 3                          28.0       41787
# 4                          28.0       13176
# ...                         ...         ...
# 9888373                    18.0       43961
# 9888374                    18.0        5622
# 9888375                    18.0       14727
# 9888376                     7.0       24852
# 9888377                    30.0       24852
#
#                               product_name  add_to_cart_order  reordered  \
# 0                   Bag of Organic Bananas                  4          0
# 1                      Organic Fuji Apples                  5          0
# 2                        Honeycrisp Apples                  6          0
# 3                           Bartlett Pears                  7          0
# 4                   Bag of Organic Bananas                  8          1
# ...                                    ...                ...        ...
# 9888373  Organic Peeled Whole Baby Carrots                 10          1
# 9888374      Cocktail Tomatoes on the Vine                 18          0
# 9888375                       Yellow Onion                 20          0
# 9888376                             Banana                  1          1
# 9888377                             Banana                  3          1
#
#          aisle_id                       aisle  total_produce_purchased  \
# 0              24                fresh fruits                        1
# 1              24                fresh fruits                        1
# 2              24                fresh fruits                        1
# 3              24                fresh fruits                        1
# 4              24                fresh fruits                        1
# ...           ...                         ...                      ...
# 9888373       123  packaged vegetables fruits                        1
# 9888374       123  packaged vegetables fruits                        1
# 9888375       123  packaged vegetables fruits                        1
# 9888376        24                fresh fruits                        1
# 9888377        24                fresh fruits                        1
#
#          organic?
# 0               1
# 1               1
# 2               0
# 3               0
# 4               1
# ...           ...
# 9888373         1
# 9888374         0
# 9888375         0
# 9888376         0
# 9888377         0
#
# [9888378 rows x 14 columns]

# %%
# Group the rows by user_id and add the previously initialized organic? column (1 for organic, 0 for non-organic)
# This returns a series with user_id, organic?

user_organic = organic.groupby('user_id')['organic?'].sum()
user_organic
# Out:
# user_id
# 1           3
# 2          21
# 3          23
# 4           2
# 5          15
#          ...
# 206205      7
# 206206     27
# 206207     47
# 206208    154
# 206209      9
# Name: organic?, Length: 194331, dtype: int32

# %%
# Combine the total and organic series into one dataframe (user_id, total_orders, organic?)
user_df = pd.concat([user_total, user_organic], axis=1).reset_index()
user_df
# Out:
#         user_id  total_produce_purchased  organic?
# 0             1                        5         3
# 1             2                       43        21
# 2             3                       38        23
# 3             4                        2         2
# 4             5                       23        15
# ...         ...                      ...       ...
# 194326   206205                       14         7
# 194327   206206                       34        27
# 194328   206207                       50        47
# 194329   206208                      197       154
# 194330   206209                       20         9
#
# [194331 rows x 3 columns]

# %%
user_df = pd.merge(user_df, unumord, on='user_id')
user_df
# Out:
#         user_id  total_produce_purchased  organic_produce_purchased  \
# 0             1                        5                          3
# 1             2                       43                         21
# 2             3                       38                         23
# 3             4                        2                          2
# 4             5                       23                         15
# ...         ...                      ...                        ...
# 194326   206205                       14                          7
# 194327   206206                       34                         27
# 194328   206207                       50                         47
# 194329   206208                      197                        154
# 194330   206209                       20                          9
#
#         organic_%           segment  order_number
# 0        0.600000  Moderate Organic             2
# 1        0.488372    Organic Taster            15
# 2        0.605263  Moderate Organic            12
# 3        1.000000     Super Organic             1
# 4        0.652174  Moderate Organic             5
# ...           ...               ...           ...
# 194326   0.500000  Moderate Organic             3
# 194327   0.794118  Moderate Organic            11
# 194328   0.940000     Super Organic            16
# 194329   0.781726  Moderate Organic            45
# 194330   0.450000    Organic Taster            11
#
# [194331 rows x 6 columns]

# %%
# Rename the organic? column to 'organic_produce_purchased'
user_df.rename(columns = {'organic?':'organic_produce_purchased', 'order_number':'number_of_orders'}, inplace = True) 
user_df
# Out:
#         user_id  total_produce_purchased  organic_produce_purchased  \
# 0             1                        5                          3
# 1             2                       43                         21
# 2             3                       38                         23
# 3             4                        2                          2
# 4             5                       23                         15
# ...         ...                      ...                        ...
# 194326   206205                       14                          7
# 194327   206206                       34                         27
# 194328   206207                       50                         47
# 194329   206208                      197                        154
# 194330   206209                       20                          9
#
#         organic_%           segment  number_of_orders
# 0        0.600000  Moderate Organic                 2
# 1        0.488372    Organic Taster                15
# 2        0.605263  Moderate Organic                12
# 3        1.000000     Super Organic                 1
# 4        0.652174  Moderate Organic                 5
# ...           ...               ...               ...
# 194326   0.500000  Moderate Organic                 3
# 194327   0.794118  Moderate Organic                11
# 194328   0.940000     Super Organic                16
# 194329   0.781726  Moderate Organic                45
# 194330   0.450000    Organic Taster                11
#
# [194331 rows x 6 columns]

# %%
# Create a new 'organic_%' column that is the percentage of organic produce purchased over total produce purchased
user_df['organic_%'] = user_df['organic_produce_purchased']/user_df['total_produce_purchased']

# %%
user_df
# Out:
#         user_id  total_produce_purchased  organic_produce_purchased  \
# 0             1                        5                          3
# 1             2                       43                         21
# 2             3                       38                         23
# 3             4                        2                          2
# 4             5                       23                         15
# ...         ...                      ...                        ...
# 194326   206205                       14                          7
# 194327   206206                       34                         27
# 194328   206207                       50                         47
# 194329   206208                      197                        154
# 194330   206209                       20                          9
#
#         organic_%           segment  number_of_orders
# 0        0.600000  Moderate Organic                 2
# 1        0.488372    Organic Taster                15
# 2        0.605263  Moderate Organic                12
# 3        1.000000     Super Organic                 1
# 4        0.652174  Moderate Organic                 5
# ...           ...               ...               ...
# 194326   0.500000  Moderate Organic                 3
# 194327   0.794118  Moderate Organic                11
# 194328   0.940000     Super Organic                16
# 194329   0.781726  Moderate Organic                45
# 194330   0.450000    Organic Taster                11
#
# [194331 rows x 6 columns]

# %%
# Create a new 'segment' column and initialize it with None
user_df['segment'] = np.NaN

# Set up the user segments per the percentage ranges below and assign the values to the 'segment' column
user_df.loc[user_df['organic_%'] < NEVER_ORGANIC_MAX, 'segment'] = 'Never Organic'
user_df.loc[(user_df['organic_%'] >= NEVER_ORGANIC_MAX) & (user_df['organic_%'] < MID), 'segment'] = 'Organic Taster'
user_df.loc[(user_df['organic_%'] >= MID) & (user_df['organic_%'] < SUPER_ORGANIC_MIN), 'segment'] = 'Moderate Organic'
user_df.loc[user_df['organic_%'] >= SUPER_ORGANIC_MIN, 'segment'] = 'Super Organic'

# %%
user_df
# Out:
#         user_id  total_produce_purchased  organic_produce_purchased  \
# 0             1                        5                          3
# 1             2                       43                         21
# 2             3                       38                         23
# 3             4                        2                          2
# 4             5                       23                         15
# ...         ...                      ...                        ...
# 194326   206205                       14                          7
# 194327   206206                       34                         27
# 194328   206207                       50                         47
# 194329   206208                      197                        154
# 194330   206209                       20                          9
#
#         organic_%           segment  number_of_orders
# 0        0.600000  Moderate Organic                 2
# 1        0.488372    Organic Taster                15
# 2        0.605263  Moderate Organic                12
# 3        1.000000     Super Organic                 1
# 4        0.652174  Moderate Organic                 5
# ...           ...               ...               ...
# 194326   0.500000  Moderate Organic                 3
# 194327   0.794118  Moderate Organic                11
# 194328   0.940000     Super Organic                16
# 194329   0.781726  Moderate Organic                45
# 194330   0.450000    Organic Taster                11
#
# [194331 rows x 6 columns]

# %%
# Filter the user dataframe by removing all users with total produce purchased <10
df_filtered = user_df[user_df['total_produce_purchased'] > 9] 
df_filtered.head(30)
# Out:
#     user_id  total_produce_purchased  organic_produce_purchased  organic_%  \
# 1         2                       43                         21   0.488372
# 2         3                       38                         23   0.605263
# 4         5                       23                         15   0.652174
# 6         7                       58                         35   0.603448
# 7         8                       40                         20   0.500000
# 9        10                       72                         27   0.375000
# 10       11                       11                          2   0.181818
# 11       12                       24                         11   0.458333
# 12       13                       17                          5   0.294118
# 13       14                       33                          5   0.151515
# 14       16                       44                         27   0.613636
# 15       17                       16                          0   0.000000
# 16       18                       21                         11   0.523810
# 18       20                       11                          0   0.000000
# 19       21                       30                         18   0.600000
# 20       22                       33                         27   0.818182
# 25       27                       67                         38   0.567164
# 26       28                       72                         32   0.444444
# 30       32                       31                         18   0.580645
# 32       34                       10                          6   0.600000
# 33       35                       78                         28   0.358974
# 34       36                       16                         13   0.812500
# 35       37                       91                         65   0.714286
# 36       38                       28                         23   0.821429
# 37       39                       55                         28   0.509091
# 38       40                       22                         13   0.590909
# 39       41                       24                         16   0.666667
# 40       42                       15                          9   0.600000
# 41       43                       59                          4   0.067797
# 42       44                       10                          2   0.200000
#
#              segment  number_of_orders
# 1     Organic Taster                15
# 2   Moderate Organic                12
# 4   Moderate Organic                 5
# 6   Moderate Organic                20
# 7   Moderate Organic                 4
# 9     Organic Taster                 5
# 10    Organic Taster                 7
# 11    Organic Taster                 5
# 12    Organic Taster                 9
# 13    Organic Taster                14
# 14  Moderate Organic                 6
# 15     Never Organic                14
# 16  Moderate Organic                 5
# 18     Never Organic                 4
# 19  Moderate Organic                17
# 20  Moderate Organic                12
# 25  Moderate Organic                24
# 26    Organic Taster                20
# 30  Moderate Organic                 5
# 32  Moderate Organic                 3
# 33    Organic Taster                 9
# 34  Moderate Organic                15
# 35  Moderate Organic                22
# 36  Moderate Organic                10
# 37  Moderate Organic                 7
# 38  Moderate Organic                 9
# 39  Moderate Organic                 6
# 40  Moderate Organic                 9
# 41     Never Organic                12
# 42    Organic Taster                 4

# %%
a = df_filtered.groupby('segment').sum()
a
# Out:
#                      user_id  total_produce_purchased  \
# segment
# Moderate Organic  7106728280                  5398847
# Never Organic     1486091000                   527700
# Organic Taster    6025665679                  3316590
# Super Organic      728087708                   427346
#
#                   organic_produce_purchased     organic_%  number_of_orders
# segment
# Moderate Organic                    3706362  46745.811139           1206072
# Never Organic                         24006    551.328998            188169
# Organic Taster                      1109260  18222.342023            859853
# Super Organic                        400502   6717.899282            117531

# %%
a.drop(['user_id', 'organic_%'], axis=1)
# Out:
#                   total_produce_purchased  organic_produce_purchased
# segment
# Moderate Organic                  5398847                    3706362
# Never Organic                      527700                      24006
# Organic Taster                    3316590                    1109260
# Super Organic                      427346                     400502

# %%
b = df_filtered.groupby('segment').count()
b
# Out:
#                   user_id  total_produce_purchased  organic_produce_purchased  \
# segment
# Moderate Organic    69074                    69074                      69074
# Never Organic       14367                    14367                      14367
# Organic Taster      58326                    58326                      58326
# Super Organic        7102                     7102                       7102
#
#                   organic_%
# segment
# Moderate Organic      69074
# Never Organic         14367
# Organic Taster        58326
# Super Organic          7102

# %%
b.drop(['total_produce_purchased', 'organic_produce_purchased', 'organic_%'], axis=1)
# Out:
#                   user_id
# segment
# Moderate Organic    69074
# Never Organic       14367
# Organic Taster      58326
# Super Organic        7102

# %%
dfm = pd.merge(a, b, on='segment')

# %%
dfm
# Out:
#                    user_id_x  total_produce_purchased_x  \
# segment
# Moderate Organic  7106728280                    5398847
# Never Organic     1486091000                     527700
# Organic Taster    6025665679                    3316590
# Super Organic      728087708                     427346
#
#                   organic_produce_purchased_x   organic_%_x  user_id_y  \
# segment
# Moderate Organic                      3706362  46745.811139      69074
# Never Organic                           24006    551.328998      14367
# Organic Taster                        1109260  18222.342023      58326
# Super Organic                          400502   6717.899282       7102
#
#                   total_produce_purchased_y  organic_produce_purchased_y  \
# segment
# Moderate Organic                      69074                        69074
# Never Organic                         14367                        14367
# Organic Taster                        58326                        58326
# Super Organic                          7102                         7102
#
#                   organic_%_y
# segment
# Moderate Organic        69074
# Never Organic           14367
# Organic Taster          58326
# Super Organic            7102

# %%
dfm.reindex(['Never Organic', 'Organic Taster', 'Moderate Organic', 'Super Organic'])
# Out:
#                    user_id_x  total_produce_purchased_x  \
# segment
# Never Organic     1486091000                     527700
# Organic Taster    6025665679                    3316590
# Moderate Organic  7106728280                    5398847
# Super Organic      728087708                     427346
#
#                   organic_produce_purchased_x   organic_%_x  user_id_y  \
# segment
# Never Organic                           24006    551.328998      14367
# Organic Taster                        1109260  18222.342023      58326
# Moderate Organic                      3706362  46745.811139      69074
# Super Organic                          400502   6717.899282       7102
#
#                   total_produce_purchased_y  organic_produce_purchased_y  \
# segment
# Never Organic                         14367                        14367
# Organic Taster                        58326                        58326
# Moderate Organic                      69074                        69074
# Super Organic                          7102                         7102
#
#                   organic_%_y
# segment
# Never Organic           14367
# Organic Taster          58326
# Moderate Organic        69074
# Super Organic            7102

# %%
fig, (ax1) = plt.subplots(2,1,figsize = (12,6), sharex=True)

ax1[0].bar(dfm.index,dfm['user_id_y'])
ax1[1].bar(dfm.index,dfm['total_produce_purchased_x'])
# Out:
# <BarContainer object of 4 artists>

# %%
# Plot the count of each segment

fig, ax = plt.subplots(1,1,figsize=(10,8))

df_filtered['segment'].value_counts().reindex(['Never Organic', 'Organic Taster', 'Moderate Organic', 'Super Organic']).plot(kind="bar", color = ['#1f77b4','#2ca02c','#ff7f0e','#d62728'])

plt.title('Histogram of User Segments')
plt.xlabel('Segments')
plt.ylabel('Number of users')
ax.get_yaxis().set_major_formatter(lambda x, loc: "{:,}".format(int(x)))
plt.xticks(rotation='horizontal')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-f59fafdedc5a> in <module>
#       8 plt.xlabel('Segments')
#       9 plt.ylabel('Number of users')
# ---> 10 ax.get_yaxis().set_major_formatter(lambda x, loc: "{:,}".format(int(x)))
#      11 plt.xticks(rotation='horizontal')
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in set_major_formatter(self, formatter)
#    1626         formatter : `~matplotlib.ticker.Formatter`
#    1627         """
# -> 1628         cbook._check_isinstance(mticker.Formatter, formatter=formatter)
#    1629         self.isDefault_majfmt = False
#    1630         self.major.formatter = formatter
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _check_isinstance(_types, **kwargs)
#    2121     for k, v in kwargs.items():
#    2122         if not isinstance(v, types):
# -> 2123             raise TypeError(
#    2124                 "{!r} must be an instance of {}, not a {}".format(
#    2125                     k,
#
# TypeError: 'formatter' must be an instance of matplotlib.ticker.Formatter, not a function

# %%
# Plot the histogram of percentage organic from 0-1

fig, ax = plt.subplots(1,1,figsize=(12,10))

N, bins, patches = plt.hist(df_filtered['organic_%']*100, bins = 100)

# Assign the colors for the bins
for i in range(0,len(patches)):
    if i < 10:
        patches[i].set_facecolor('#1f77b4')
    if i >= 10 and i < 50:
        patches[i].set_facecolor('#2ca02c')
    if i >= 50 and i < 90:
        patches[i].set_facecolor('#ff7f0e')
    if i >= 90:
        patches[i].set_facecolor('#d62728')  
    
    
ax.get_yaxis().set_major_formatter(lambda x, loc: "{:,}".format(int(x)))    
    
plt.title('Histogram of the Organic Percentage of User Produce Orders')
plt.xlabel('Percentage (%)')
plt.ylabel('Number of users')
plt.xlim(0,100)
plt.xticks(np.arange(0,110,10))



# Create a corresponding legend
handles = [Rectangle((0,0),1,1,color=c,ec="k") for c in ['#1f77b4','#2ca02c','#ff7f0e','#d62728']]
labels= ["Never Organic", "Organic Taster", "Moderate Organic", "Super Organic"]
plt.legend(handles, labels)

pass
